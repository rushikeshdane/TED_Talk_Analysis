# %%
import pandas as pd
import nltk
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# import chart_studio.plotly as py
# import chart_studio.tools as tls

# %%
df=pd.read_csv('data.csv')

# %%
most_viewed_ted_talk=df.sort_values('views',ascending=False).head(20)
most_viewed_ted_talk.head(10)
# Out:
#                                                   title            author  \
# 5436                        Do schools kill creativity?  Sir Ken Robinson
# 4084           Your body language may shape who you are         Amy Cuddy
# 2958         Inside the mind of a master procrastinator         Tim Urban
# 4765                   How great leaders inspire action       Simon Sinek
# 4605                         The power of vulnerability       Brené Brown
# 3504         How to speak so that people want to listen   Julian Treasure
# 2168                     My philosophy for a happy life         Sam Berns
# 3251                 The next outbreak? We're not ready        Bill Gates
# 3017  What makes a good life? Lessons from the longe...  Robert Waldinger
# 3994  Looks aren't everything. Believe me, I'm a model.   Cameron Russell
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# ...

# %%
most_viewed_ted_talk=df.sort_values('views',ascending=False).head(20)
most_viewed_ted_talk.head(10)
# Out:
#                                                   title            author  \
# 5436                        Do schools kill creativity?  Sir Ken Robinson
# 4084           Your body language may shape who you are         Amy Cuddy
# 2958         Inside the mind of a master procrastinator         Tim Urban
# 4765                   How great leaders inspire action       Simon Sinek
# 4605                         The power of vulnerability       Brené Brown
# 3504         How to speak so that people want to listen   Julian Treasure
# 2168                     My philosophy for a happy life         Sam Berns
# 3251                 The next outbreak? We're not ready        Bill Gates
# 3017  What makes a good life? Lessons from the longe...  Robert Waldinger
# 3994  Looks aren't everything. Believe me, I'm a model.   Cameron Russell
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# ...

# %%
fig1 = px.bar(data_frame=most_viewed_ted_talk,y='title',x='views',orientation='h', color='title', width=1000, height=600,
              color_discrete_sequence=['#800000'],template='simple_white',text='author'
           #color_continuous_scale='darkmint'
            )
fig1.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Top 20 Most Viewed TED Talk </b>", 'font': {'size': 30}},title_x=0.6,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'>Views</b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue';></b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')
fig1.update_traces(showlegend=False)
fig1.show()

# %% [markdown]
#  # most liked ted talk

# %%
most_liked_ted_talk=df.sort_values('likes',ascending=False).head(20)
most_liked_ted_talk.head(20)
# Out:
#                                                   title  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4605                         The power of vulnerability
# 4765                   How great leaders inspire action
# 3504         How to speak so that people want to listen
# 2168                     My philosophy for a happy life
# 3251                 The next outbreak? We're not ready
# 3017  What makes a good life? Lessons from the longe...
# 4990             10 things you didn't know about orgasm
# 2166                 Why people believe they can't draw
# 3994  Looks aren't everything. Believe me, I'm a model.
# 3799                          The orchestra in my mouth
# 4407                                 How to spot a liar
# 3758                            The art of misdirection
# 4280                            The power of introverts
# ...

# %%
fig2 = px.bar(data_frame=most_liked_ted_talk,y='title',x='likes',orientation='h', color='title', width=1000, height=600,
              color_discrete_sequence=['red'],template='simple_white',text='author'
           #color_continuous_scale='darkmint'
            )
fig2.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Top 20 Most Liked TED Talk </b>", 'font': {'size': 30}},title_x=0.6,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'>Likes</b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue';></b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')

fig2.update_traces(showlegend=False)
fig2.show()

# %% [markdown]
# # most viewd speaker

# %%
liked_speaker=df.groupby(['author']).sum()

# %%
liked_speaker
likes=liked_speaker.sort_values(by ='likes',ascending=True).tail(10)
likes
# Out:
#                       views    likes
# author
# Mia Nacamulli      44174000  1395000
# Iseult Gillespie   54998000  1660900
# Tim Urban          60000000  1800000
# Julian Treasure    64300000  1870000
# Amy Cuddy          64000000  1900000
# Brené Brown        72000000  2204000
# Simon Sinek        74800000  2246000
# Bill Gates         77800000  2349000
# Sir Ken Robinson   95654000  2833600
# Alex Gendler      187196000  5691000

# %%
fig3 = px.pie(data_frame=likes,names=likes.index,values='likes', width=1000, height=600,
              color_discrete_sequence=px.colors.sequential.Reds_r,template='simple_white'      #color_continuous_scale='darkmint'
            )
fig3.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Distribution of Top 10 Most Liked Speakers</b>", 'font': {'size': 30}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black")
fig3.update_traces(textposition='inside', textinfo='percent+label',showlegend=False)
fig3.show()

# %%
fig4 = px.bar(data_frame=likes,y=likes.index,x='likes',orientation='h', width=1000, height=600,
              color_discrete_sequence=['red'],template='simple_white'     #color_continuous_scale='darkmint'
            )
fig4.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Top 10 Most Liked Speakers </b>", 'font': {'size': 30}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'>Likes</b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue';></b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')

fig4.update_traces(showlegend=False)
fig4.show()
#py.plot(fig, filename="ted_talk_likes", auto_open = True)

# %%
views = liked_speaker.sort_values(by ='views',ascending=True).tail(10)
views
# Out:
#                       views    likes
# author
# Mia Nacamulli      44174000  1395000
# Iseult Gillespie   54998000  1660900
# Tim Urban          60000000  1800000
# Amy Cuddy          64000000  1900000
# Julian Treasure    64300000  1870000
# Brené Brown        72000000  2204000
# Simon Sinek        74800000  2246000
# Bill Gates         77800000  2349000
# Sir Ken Robinson   95654000  2833600
# Alex Gendler      187196000  5691000

# %%
fig5 = px.bar(data_frame=views,y=views.index,x='views',orientation='h', width=1000, height=600,
              color_discrete_sequence=['#800000'],template='simple_white'          #color_continuous_scale='darkmint'
            )
fig5.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Top 10 Most Viewed Speakers </b>", 'font': {'size': 30}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'>Views</b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue';></b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')
fig5.update_traces(showlegend=False)
fig5.show()

# %%
fig6 = px.pie(data_frame=views,names=views.index,values='views', width=1000, height=600,
              color_discrete_sequence=px.colors.sequential.Reds_r,template='simple_white'      #color_continuous_scale='darkmint'
            )
fig6.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Distribution of Top 10 Most Viewed Speakers</b>", 'font': {'size': 30}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black")
fig6.update_traces(textposition='inside', textinfo='percent+label',showlegend=False)
fig6.show()

# %% [markdown]
# # which speaker given most number of ted talks

# %%
author_count =df.author.value_counts()[df.author.value_counts()> 5]

# %%
fig7 = px.pie(data_frame=author_count,names=author_count.index,values=author_count, width=1000, height=600,
              color_discrete_sequence=px.colors.sequential.Reds_r,template='simple_white'   #color_continuous_scale='darkmint'
            )
fig7.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Distribution of Speakers with Most Number of TED Talks</b>", 'font': {'size': 23}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black")
fig7.update_traces(textposition='inside', textinfo='percent+label',showlegend = False)
fig7.show()

# %%
fig8 = px.bar(x=author_count.index ,y = author_count,width=1000, height=600,
              color_discrete_sequence=['#FA8072'],template='simple_white')
fig8.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Speakers with Most Number of TED Talks </b>", 'font': {'size': 28}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'></b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue';>Number of TED Talk</b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')
fig8.update_traces(showlegend=False)
fig8.show()

# %%
px.funnel(y=author_count.index ,x = author_count,width=1000, height=600,
              color_discrete_sequence=px.colors.qualitative.Prism_r,template='simple_white')

# %%
df['views to like ratio'] = round(df['views'] / df['likes'],2)

# %%
top_10_by_vl_ratio =df.sort_values("views to like ratio").tail(10)

# %%
fig9 = px.bar(data_frame=top_10_by_vl_ratio,y='title',x='views to like ratio',orientation='h', color='title', width=1000, height=600,
              color_discrete_sequence=['#FF2800'],template='simple_white',text='author'
           #color_continuous_scale='darkmint' .qualitative.Prism_r
            )
fig9.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Top 10 TED Talk with best views to like ratio </b>", 'font': {'size': 30}},title_x=0.6,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'>views to like ratio</b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue;'></b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')

fig9.update_traces(showlegend=False)
fig9.show()

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
comment_words = ''
for line in df.title:
    words = line.lower().split()
    comment_words += " ".join(words)+" "

# %%
wordcloud = WordCloud(width = 1000, height = 800, background_color ='pink', stopwords = stopwords, min_font_size = 10).generate(comment_words)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
plt.savefig('wordcloud.png',trasparent = True)
# Out:
# D:\anaconda\envs\panal\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning:
#
# savefig() got unexpected keyword argument "trasparent" which is no longer supported as of 3.3 and will become an error in 3.6

# %%
def month(x):
    
    var = x.split(' ')[0]
    return var

# %%
df['month'] = df['date'].apply(month)
df['year'] =df['date'].apply(lambda x: x.split(' ')[1])

# %%
df.year.value_counts()
df.month.value_counts()
fig10 = px.bar(y=df.year.value_counts(),x=df.year.value_counts().index,orientation='v', width=900, height=600,
              color_discrete_sequence=['red'],template='simple_white'
           #color_continuous_scale='darkmint'
            )
'''fig.update_xaxes(categoryorder='array', categoryarray= ['1970','1972','1983','1984','1990', '1991', '1994', '1998',
                                                        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
                                                        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
                                                        '2017', '2018', '2019', '2020', '2021', '2022'])'''
fig10.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'> TED Talk Frequency per Year</b>", 'font': {'size': 30}},title_x=0.55,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'>Year</b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue;'>Number of Ted Talks</b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')
fig10.show()

# %%
fig11 = px.pie(values=df.year.value_counts(),names=df.year.value_counts().index, width=1000, height=600,
              color_discrete_sequence=px.colors.sequential.Reds_r,template='simple_white'   #color_continuous_scale='darkmint'
            )
fig11.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Year Wise Distribution</b>", 'font': {'size': 30}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black")
fig11.update_traces(textposition='inside', textinfo='percent+label',showlegend=False)
fig11.show()

# %%
fig12 = px.bar(y=df.month.value_counts(),x=df.month.value_counts().index,orientation='v', width=900, height=600,
              color_discrete_sequence=['red'],template='simple_white'
           #color_continuous_scale='darkmint'
            )
fig12.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'> TED Talk Frequency per Month</b>", 'font': {'size': 30}},title_x=0.55,
    
     title_font_family="Times New Roman",
    title_font_color="black",
   # font_color='blue',
    
xaxis_title={'text': "<b style:'color:blue;'>Month</b>", 'font': {'size':15}},
yaxis_title={'text': "<b style:'color:blue;'>Number of Ted Talks</b>", 'font': {'size': 15}}, paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)')

fig12.update_xaxes(categoryorder='array', categoryarray= [ 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
fig12.show()

# %%
l=[]
for i in df.year.unique():
    l.append(int(i))
new_list =sorted(l)

l2 = [str(i) for i in new_list]
l2
# Out:
# ['1970',
#  '1972',
#  '1983',
#  '1984',
#  '1990',
#  '1991',
#  '1994',
#  '1998',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022']

# %%
fig13 = px.pie(values=df.month.value_counts(),names=df.month.value_counts().index, width=1000, height=600,
              color_discrete_sequence=px.colors.sequential.Reds_r,template='simple_white'   #color_continuous_scale='darkmint'
            )
fig13.update_layout(
    autosize=True,
    title ={'text': "<b style:'color:blue;'>Month Wise Distribution</b>", 'font': {'size': 30}},title_x=0.5,
    
     title_font_family="Times New Roman",
    title_font_color="black")
fig13.update_traces(textposition='inside', textinfo='percent+label',showlegend=False)
fig13.show()
